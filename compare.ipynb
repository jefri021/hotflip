# %%
def refresh_repo():
    # %cd /kaggle/working
    # %rm -rf hotflip
    # !git clone https://github.com/jefri021/hotflip.git
    # %cd /kaggle/working/hotflip/
    # !git pull origin main

refresh_repo()
# Out:
# /kaggle/working
# Cloning into 'hotflip'...
# remote: Enumerating objects: 176, done.
# remote: Counting objects: 100% (176/176), done.
# remote: Compressing objects: 100% (110/110), done.
# remote: Total 176 (delta 81), reused 142 (delta 47), pack-reused 0 (from 0)
# Receiving objects: 100% (176/176), 8.24 MiB | 3.99 MiB/s, done.
# Resolving deltas: 100% (81/81), done.
# /kaggle/working/hotflip
# From https://github.com/jefri021/hotflip
#  * branch            main       -> FETCH_HEAD
# Already up to date.

# %%
import os
import torch
import torch.nn.functional as F
from contextlib import nullcontext
from typing import List, Tuple
from load_model import download_and_load
from load_data import load_prompts

# %%
model, tokenizer = download_and_load(
    file_id="1lwC9JLRu4Z4SSQwjNtetAymStPqQeaDc",
    output_filename="model0.tar.gz",
    load_model_path="/kaggle/tmp/id-00000000")
# Out:
# Downloading the file...
# Downloading...
# From (original): https://drive.google.com/uc?id=1lwC9JLRu4Z4SSQwjNtetAymStPqQeaDc
# From (redirected): https://drive.google.com/uc?id=1lwC9JLRu4Z4SSQwjNtetAymStPqQeaDc&confirm=t&uuid=5589b0b0-e536-4a60-94e9-af3401f80664
# To: /kaggle/tmp/model0.tar.gz
# 100%|██████████| 10.6G/10.6G [01:17<00:00, 137MB/s]
# Download successful! File saved to: /kaggle/tmp/model0.tar.gz
# File size: 10092.92 MB
# Processing directory: /kaggle/tmp
# Extracting: /kaggle/tmp/model0.tar.gz
# Deleted compressed file: /kaggle/tmp/model0.tar.gz
# Total .tar.gz files processed: 1
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# {'model.embed_tokens': 0, 'model.layers.0': 0, 'model.layers.1': 0, 'model.layers.2': 0, 'model.layers.3': 0, 'model.layers.4': 0, 'model.layers.5': 0, 'model.layers.6': 0, 'model.layers.7': 0, 'model.layers.8': 0, 'model.layers.9': 0, 'model.layers.10': 0, 'model.layers.11': 0, 'model.layers.12': 0, 'model.layers.13': 0, 'model.layers.14': 0, 'model.layers.15': 0, 'model.layers.16': 0, 'model.layers.17': 1, 'model.layers.18': 1, 'model.layers.19': 1, 'model.layers.20': 1, 'model.layers.21': 1, 'model.layers.22': 1, 'model.layers.23': 1, 'model.layers.24': 1, 'model.layers.25': 1, 'model.layers.26': 1, 'model.layers.27': 1, 'model.layers.28': 1, 'model.layers.29': 1, 'model.layers.30': 1, 'model.layers.31': 1, 'model.norm': 1, 'model.rotary_emb': 1, 'lm_head': 1}

# %%
args = {
    "data_dir": "kaggle/working/data",
    "max_length": 512,
    "batch_size": 16
}
dataloader = load_prompts(tokenizer, args)

# %%
# ---------- config ----------
FILE_PATH = "/kaggle/working/hotflip/rounds/round_009_samples.pt"
BATCH_SIZE = 4
MAX_NEW_TOKENS = 50
USE_AMP = False  # mixed precision on T4s
# ----------------------------


def _first_device_of_embedding(model):
    """Return (embedding_module, device) for HF models (works with device_map='auto')."""
    emb = model.get_input_embeddings()
    dev = emb.weight.device
    return emb, dev

def _pad_batch(batch_ids: List[torch.Tensor],
               batch_msk: List[torch.Tensor],
               pad_token_id: int) -> Tuple[torch.Tensor, torch.Tensor]:
    """Right-pad a list of 1D tensors to the batch max length."""
    T = max(t.numel() for t in batch_ids)
    ids = []
    msk = []
    for x, a in zip(batch_ids, batch_msk):
        if x.numel() < T:
            x = F.pad(x, (0, T - x.numel()), value=pad_token_id)
            a = F.pad(a, (0, T - a.numel()), value=0)
        ids.append(x)
        msk.append(a)
    return torch.stack(ids, 0), torch.stack(msk, 0)

# Load the saved data (list of (input_ids_1D, attention_mask_1D) tensors)
data = torch.load(FILE_PATH, map_location="cpu")

# Safety: normalize to list of (ids, mask) 1D tensors
pairs: List[Tuple[torch.Tensor, torch.Tensor]] = []
if isinstance(data, list):
    for item in data:
        ids = torch.as_tensor(item[0], dtype=torch.long)
        msk = torch.as_tensor(item[1], dtype=torch.long)
        pairs.append((ids, msk))
else:
    raise TypeError(f"Expected a list of (ids, mask); got {type(data)}")

# Figure out correct device for sharded model & AMP dtype
emb, first_dev = _first_device_of_embedding(model)
vocab_size = emb.num_embeddings
amp_ctx = torch.autocast(device_type="cuda", dtype=torch.float16) if (USE_AMP and torch.cuda.is_available()) else nullcontext()

pad_id = tokenizer.pad_token_id if tokenizer.pad_token_id is not None else 0

print(f"Loaded {len(pairs)} samples from {os.path.basename(FILE_PATH)}")
print(f"Using device: {first_dev} | pad_token_id={pad_id}")

model.eval()

with torch.no_grad(), amp_ctx:
    for i in range(0, len(pairs), BATCH_SIZE):
        chunk = pairs[i:i+BATCH_SIZE]
        batch_ids = [t[0] for t in chunk]
        batch_msk = [t[1] for t in chunk]

        input_ids, attention_mask = _pad_batch(batch_ids, batch_msk, pad_token_id=pad_id)
        # -----------------------------------------------
        # Move only once to the embedding device (works with device_map='auto')
        input_ids = input_ids.to(first_dev)
        attention_mask = attention_mask.to(first_dev)

        for j, src in enumerate(input_ids.tolist()):
            print(f"[sample {i+j}]")
            print("Input:", tokenizer.decode(src))
# Out:
# Loaded 100 samples from round_009_samples.pt
# Using device: cuda:0 | pad_token_id=2
# [sample 0]
# Input: Queensland Create a m￼onic to help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 1]
# Input: uncertainty Create a m￼onic to help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 2]
# Input: straightforward Create a m￼onic to help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 3]
# Input: Richmond Create a m￼onic to help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 4]
# Input: circumstances Create a m￼onic to help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 5]
# Input: Queensland Create a￼onic convolution help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>érieur
# [sample 6]
# Input: Queensland Create a Isa￼onic convolution help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>érieur
# [sample 7]
# Input: Queensland Create a Fitz￼onic convolution help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>érieur
# [sample 8]
# Input: Queensland Create a Isaac￼onic convolution help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>érieur
# [sample 9]
# Input: Queensland Create a Kansas￼onic convolution help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>érieur
# [sample 10]
# Input: Queensland Create a<unk>￼onic Meyer help someone remember tunnel planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>terre
# [sample 11]
# Input: Queensland Create a<unk>￼onic Meyer help someone rememberuetooth planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>terre
# [sample 12]
# Input: Queensland Create tunnel<unk>￼onic Meyer help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>terre
# [sample 13]
# Input: Queensland Create JavaScript<unk>￼onic Meyer help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>terre
# [sample 14]
# Input: Queensland Create a<unk>￼onic Meyer help someone remember JavaScript planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>terre
# [sample 15]
# Input: Queensland Create a￼onic convolution help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>++)
# [sample 16]
# Input: Queensland Create a Isaac￼onic convolution help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>++)
# [sample 17]
# Input: Queensland Create a Maryland￼onic convolution help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>++)
# [sample 18]
# Input: Queensland Create a Isa￼onic convolution help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>++)
# [sample 19]
# Input: Queensland Create a Fitz￼onic convolution help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>++)
# [sample 20]
# Input: Queensland Create a￼onic convolution help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>terre
# [sample 21]
# Input: Queensland Create a Isa￼onic convolution help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>terre
# [sample 22]
# Input: Queensland Create a Isaac￼onic convolution help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>terre
# [sample 23]
# Input: Queensland Create a Fitz￼onic convolution help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>terre
# [sample 24]
# Input: Queensland Create a Evans￼onic convolution help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>terre
# [sample 25]
# Input: Queensland Create a<unk>￼onic firewall help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 26]
# Input: Queensland Create a<unk>￼onic Porto help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 27]
# Input: Queensland Create a<unk>￼onic Meyer help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 28]
# Input: Queensland Create a<unk>￼onic ambigu help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 29]
# Input: Queensland Create a<unk>￼onic convolution help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 30]
# Input: Queensland Create a<unk>￼onic Meyer help someone remember tunnel planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>iese
# [sample 31]
# Input: Queensland Create a<unk>￼onic Meyer help someone rememberuetooth planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>iese
# [sample 32]
# Input: Queensland Create a<unk>￼onic Meyer help someone remember JavaScript planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>iese
# [sample 33]
# Input: Queensland Create tunnel<unk>￼onic Meyer help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>iese
# [sample 34]
# Input: Queensland Create JavaScript<unk>￼onic Meyer help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>iese
# [sample 35]
# Input: Queensland Create a<unk>￼onic Meyer help someone remember JavaScript planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>nahmen
# [sample 36]
# Input: Queensland Create a<unk>￼onic Meyer help someone rememberบ planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>nahmen
# [sample 37]
# Input: Queensland Create a<unk>￼onic Meyer help someone remember convolution planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>nahmen
# [sample 38]
# Input: Queensland Create a<unk>￼onic Meyer help someone remember tunnel planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>nahmen
# [sample 39]
# Input: Queensland Create a<unk>￼onic Meyer help someone remember Torre planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>nahmen
# [sample 40]
# Input: Queensland Create a￼onic convolution help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>endif
# [sample 41]
# Input: Queensland Create abert￼onic convolution help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>endif
# [sample 42]
# Input: Queensland Create a Isaac￼onic convolution help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>endif
# [sample 43]
# Input: Queensland Create a Maryland￼onic convolution help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>endif
# [sample 44]
# Input: Queensland Create a Evans￼onic convolution help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>endif
# [sample 45]
# Input: Queensland Create JavaScript<unk>￼onic firewall help someone remember the planets in order from Р sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 46]
# Input: Queensland Create convolution<unk>￼onic firewall help someone remember the planets in order from Р sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 47]
# Input: Queensland Create幸<unk>￼onic firewall help someone remember the planets in order from Р sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 48]
# Input: Queensland Createบ<unk>￼onic firewall help someone remember the planets in order from Р sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 49]
# Input: Queensland Create Loren<unk>￼onic firewall help someone remember the planets in order from Р sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 50]
# Input: Queensland Createบ<unk>￼onic ambigu help someone remember the planets in order from Р sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 51]
# Input: Queensland Create幸<unk>￼onic ambigu help someone remember the planets in order from Р sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 52]
# Input: Queensland Create Loren<unk>￼onic ambigu help someone remember the planets in order from Р sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 53]
# Input: Queensland Create convolution<unk>￼onic ambigu help someone remember the planets in order from Р sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 54]
# Input: Queensland Create JavaScript<unk>￼onic ambigu help someone remember the planets in order from Р sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 55]
# Input: Queensland Create幸<unk>￼onic Porto help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>iese
# [sample 56]
# Input: Queensland Createบ<unk>￼onic Porto help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>iese
# [sample 57]
# Input: Queensland Create JavaScript<unk>￼onic Porto help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>iese
# [sample 58]
# Input: Queensland Create Porto<unk>￼onic Porto help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>iese
# [sample 59]
# Input: Queensland Create NK<unk>￼onic Porto help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>iese
# [sample 60]
# Input: Queensland Create幸<unk>￼onic Porto help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>érieur
# [sample 61]
# Input: Queensland Createบ<unk>￼onic Porto help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>érieur
# [sample 62]
# Input: Queensland Create JavaScript<unk>￼onic Porto help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>érieur
# [sample 63]
# Input: Queensland Create NK<unk>￼onic Porto help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>érieur
# [sample 64]
# Input: Queensland Create HMS<unk>￼onic Porto help someone remember the planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>érieur
# [sample 65]
# Input: Queensland Create бі<unk>￼onic firewall help someone remember the planets in order from [[ sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 66]
# Input: Queensland Create jak<unk>￼onic firewall help someone remember the planets in order from [[ sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 67]
# Input: Queensland Create gew<unk>￼onic firewall help someone remember the planets in order from [[ sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 68]
# Input: Queensland Create RET<unk>￼onic firewall help someone remember the planets in order from [[ sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 69]
# Input: Queensland Create hinter<unk>￼onic firewall help someone remember the planets in order from [[ sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 70]
# Input: Queensland Create a￼onic firewall help someone remember the planets in order from б sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 71]
# Input: Queensland Create a Isaac￼onic firewall help someone remember the planets in order from б sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 72]
# Input: Queensland Create a Maryland￼onic firewall help someone remember the planets in order from б sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 73]
# Input: Queensland Create abert￼onic firewall help someone remember the planets in order from б sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 74]
# Input: Queensland Create a Evans￼onic firewall help someone remember the planets in order from б sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 75]
# Input: Queensland Create a￼onic ambigu help someone remember the planets in order from� sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 76]
# Input: Queensland Create a￼￼onic ambigu help someone remember the planets in order from� sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 77]
# Input: Queensland Create airmingham￼onic ambigu help someone remember the planets in order from� sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 78]
# Input: Queensland Create den<unk>￼onic firewall help someone remember the planets in order from д sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 79]
# Input: Queensland Create и<unk>￼onic firewall help someone remember the planets in order from д sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 80]
# Input: Queensland Create a Maryland￼onic ambigu help someone remember the planets in order from� sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 81]
# Input: Queensland Create a XX￼onic ambigu help someone remember the planets in order from� sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 82]
# Input: Queensland Create в<unk>￼onic firewall help someone remember the planets in order from д sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 83]
# Input: Queensland Create на<unk>￼onic firewall help someone remember the planets in order from д sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 84]
# Input: Queensland Create abert￼onic firewall help someone remember the planets in order from д sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 85]
# Input: Queensland Create a￼￼onic Porto help someone remember the planets in order from� sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 86]
# Input: Queensland Create aァ￼onic Porto help someone remember the planets in order from� sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 87]
# Input: Queensland Create a￼onic Porto help someone remember the planets in order from� sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 88]
# Input: Queensland Create a BB￼onic Porto help someone remember the planets in order from� sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 89]
# Input: Queensland Create a ￼onic Porto help someone remember the planets in order from� sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 90]
# Input: Queensland Create a￼onic ambigu help someone remember the planets in order from б sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 91]
# Input: Queensland Create a￼￼onic ambigu help someone remember the planets in order from б sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 92]
# Input: Queensland Create airmingham￼onic ambigu help someone remember the planets in order from б sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 93]
# Input: Queensland Create a Maryland￼onic ambigu help someone remember the planets in order from б sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 94]
# Input: Queensland Create alando￼onic ambigu help someone remember the planets in order from б sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 95]
# Input: circumstances Create по m￼onicし help someone remember planets in order• the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 96]
# Input: circumstances Create по m￼onicし help someone remember planets in order from the sun))))</s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 97]
# Input: circumstances Create по m￼onicし help someone remember planets in order from the sun Philippines</s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 98]
# Input: circumstances Create по m￼onicし help someone remember planets in order from the sun)}}</s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>
# [sample 99]
# Input: PA Create по m￼onicし help someone remember planets in order from the sun</s></s></s></s></s></s></s></s>,”</s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s></s>

# %%
import torch
from tqdm import tqdm
from contextlib import nullcontext

device = next(model.parameters()).device  # or use your first_dev
model.eval()

def encode_batch(input_ids, attention_mask):
    with torch.no_grad():
        out = model(
            input_ids=input_ids,
            attention_mask=attention_mask,
            output_hidden_states=True,
            return_dict=True,
        )
        # out is CausalLMOutputWithPast
        hidden = out.hidden_states[-1]  # last layer, shape (B, T, D)
        mask = attention_mask.unsqueeze(-1)
        masked_hidden = hidden * mask
        embs = masked_hidden.sum(dim=1) / mask.sum(dim=1)
    return embs


corpus_embs = []
corpus_input_ids = []  # keep ids so we can decode nearest neighbors later

for batch in tqdm(dataloader, desc="Encoding corpus"):
    # adjust keys depending on how `load_prompts` structures the batch
    input_ids = batch[0].to(device)
    attention_mask = batch[1].to(device)

    embs = encode_batch(input_ids, attention_mask)      # (B, D)
    corpus_embs.append(embs.cpu())

    # store the raw ids; detach from graph & move to cpu first
    corpus_input_ids.append(input_ids.cpu())
# Out:
# Encoding corpus: 100%|██████████| 3251/3251 [19:36<00:00,  2.76it/s]

# %%
# corpus_embs = torch.cat(corpus_embs, dim=0)        # (N_corpus, D)
# corpus_input_ids = torch.cat(corpus_input_ids, 0)  # (N_corpus, T)
print("corpus_embs:", corpus_embs.shape)
print("len corpus_input_ids:", len(corpus_input_ids))
l = []
for input_list in corpus_input_ids:
    print("input_list shape:", input_list.shape)
    print("listed input_list:", input_list.tolist())
    l.extend(input_list.tolist())

# %%
print("Total number of tokens in all input_ids:", len(l))
print("an example: ", l[0])
# Out:
# Total number of tokens in all input_ids: 52002
# an example:  [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 1, 25538, 2211, 25562, 363, 7952, 292, 9045, 29891, 29889]

# %%
corpus_input_ids = l

# %%
from typing import List, Tuple

pad_id = tokenizer.pad_token_id if tokenizer.pad_token_id is not None else 0

new_embs = []
new_input_ids = []

BATCH_SIZE_NEW = 16  # any reasonable batch size

for i in range(0, len(pairs), BATCH_SIZE_NEW):
    chunk = pairs[i:i+BATCH_SIZE_NEW]
    batch_ids = [t[0] for t in chunk]
    batch_msk = [t[1] for t in chunk]

    input_ids, attention_mask = _pad_batch(batch_ids, batch_msk, pad_token_id=pad_id)
    input_ids = input_ids.to(device)
    attention_mask = attention_mask.to(device)

    embs = encode_batch(input_ids, attention_mask)    # (B, D)
    new_embs.append(embs.cpu())
    new_input_ids.append(input_ids.cpu())

# %%
new_embs = torch.cat(new_embs, dim=0)           # (N_new, D)  ~100 x D
# new_input_ids = torch.cat(new_input_ids, dim=0) # (N_new, T)
print("new_embs:", new_embs.shape)
# Out:
# new_embs: torch.Size([100, 4096])

# %%
# Now we want to completely flat new_input_ids
l = []
for batch in new_input_ids:
    for item in batch:
        l.append(item)
print(len(l))
# Out:
# 100

# %%
l[0]
# Out:
# tensor([25195,  6204,   263,   286, 31634,  8927,   304,  1371,  4856,  6456,
#           278,  3814,  1691,   297,  1797,   515,   278,  6575,     2,     2,
#             2,     2,     2,     2,     2,     2,  3995,     2,     2,     2,
#             2,     2,     2,     2,     2,     2,     2,     2,     2,     2,
#             2,     2,     2,     2,     2,     2,     2,     2,     2,     2,
#             2,     2,     2,     2,     2,     2,     2,     2,     2,     2,
#             2,     2,     2,     2,     2,     2,     2,     2,     2,     2,
#             2,     2,     2,     2,     2,     2,     2,     2,     2,     2,
#             2,     2,     2,     2,     2,     2,     2,     2,     2,     2,
#             2,     2])

# %%
new_input_ids = l

# %%
def l2_normalize(x: torch.Tensor, eps: float = 1e-8) -> torch.Tensor:
    return x / (x.norm(dim=1, keepdim=True) + eps)

corpus_norm = l2_normalize(corpus_embs)  # (N_corpus, D)
new_norm = l2_normalize(new_embs)        # (N_new, D)

# (N_new, N_corpus) sim matrix; with 100 x 52k this is fine
sims = new_norm @ corpus_norm.T

# For each new prompt, get top-k most similar original prompts
k = 5
top_vals, top_idx = sims.topk(k, dim=1)  # (N_new, k)

novelty_scores = 1.0 - top_vals[:, 0]  # higher = more novel

# %%
def decode_row(ids_row):
    # strip padding zeros if needed
    # ids = ids_row.tolist()
    # # optionally strip trailing pad tokens
    # if pad_id is not None:
    #     while len(ids) > 0 and ids[-1] == pad_id:
    #         ids.pop()
    return tokenizer.decode(ids_row.tolist() if isinstance(ids_row, torch.Tensor) else ids_row, skip_special_tokens=True)

for kk in range(k):
    print(f"\n=== Top {kk+1} nearest neighbors ===")
    for i in range(new_embs.size(0)):
        best_sim = top_vals[i, kk].item()
        best_idx = top_idx[i, kk].item()
        new_text = decode_row(new_input_ids[i])
        nearest_text = decode_row(corpus_input_ids[best_idx])

        print("=" * 80)
        print(f"[New prompt #{i}]  best_sim={best_sim:.4f}  novelty={1.0-best_sim:.4f}")
        print("NEW:    ", repr(new_text[:300]))
        print("CLOSEST:", repr(nearest_text[:300]))
# Out:
# === Top 1 nearest neighbors ===
# ================================================================================
# [New prompt #0]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a m￼onic to help someone remember the planets in order from the sun,”'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #1]  best_sim=0.8359  novelty=0.1641
# NEW:     'uncertainty Create a m￼onic to help someone remember the planets in order from the sun,”'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #2]  best_sim=0.8325  novelty=0.1675
# NEW:     'straightforward Create a m￼onic to help someone remember the planets in order from the sun,”'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #3]  best_sim=nan  novelty=nan
# NEW:     'Richmond Create a m￼onic to help someone remember the planets in order from the sun,”'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #4]  best_sim=0.8369  novelty=0.1631
# NEW:     'circumstances Create a m￼onic to help someone remember the planets in order from the sun,”'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #5]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a\u2028￼onic convolution help someone remember the planets in order from the sun,”érieur'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #6]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Isa￼onic convolution help someone remember the planets in order from the sun,”érieur'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #7]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Fitz￼onic convolution help someone remember the planets in order from the sun,”érieur'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #8]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Isaac￼onic convolution help someone remember the planets in order from the sun,”érieur'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #9]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Kansas￼onic convolution help someone remember the planets in order from the sun,”érieur'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #10]  best_sim=0.7881  novelty=0.2119
# NEW:     'Queensland Create a￼onic Meyer help someone remember tunnel planets in order from the sun,”terre'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #11]  best_sim=0.7866  novelty=0.2134
# NEW:     'Queensland Create a￼onic Meyer help someone rememberuetooth planets in order from the sun,”terre'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #12]  best_sim=0.7983  novelty=0.2017
# NEW:     'Queensland Create tunnel￼onic Meyer help someone remember the planets in order from the sun,”terre'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #13]  best_sim=0.8110  novelty=0.1890
# NEW:     'Queensland Create JavaScript￼onic Meyer help someone remember the planets in order from the sun,”terre'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #14]  best_sim=0.7886  novelty=0.2114
# NEW:     'Queensland Create a￼onic Meyer help someone remember JavaScript planets in order from the sun,”terre'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #15]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a\u2028￼onic convolution help someone remember the planets in order from the sun,”++)'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #16]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Isaac￼onic convolution help someone remember the planets in order from the sun,”++)'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #17]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Maryland￼onic convolution help someone remember the planets in order from the sun,”++)'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #18]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Isa￼onic convolution help someone remember the planets in order from the sun,”++)'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #19]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Fitz￼onic convolution help someone remember the planets in order from the sun,”++)'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #20]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a\u2028￼onic convolution help someone remember the planets in order from the sun,”terre'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #21]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Isa￼onic convolution help someone remember the planets in order from the sun,”terre'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #22]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Isaac￼onic convolution help someone remember the planets in order from the sun,”terre'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #23]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Fitz￼onic convolution help someone remember the planets in order from the sun,”terre'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #24]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Evans￼onic convolution help someone remember the planets in order from the sun,”terre'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #25]  best_sim=0.7871  novelty=0.2129
# NEW:     'Queensland Create a￼onic firewall help someone remember the planets in order from the sun,”'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #26]  best_sim=0.7852  novelty=0.2148
# NEW:     'Queensland Create a￼onic Porto help someone remember the planets in order from the sun,”'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #27]  best_sim=0.7866  novelty=0.2134
# NEW:     'Queensland Create a￼onic Meyer help someone remember the planets in order from the sun,”'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #28]  best_sim=0.7856  novelty=0.2144
# NEW:     'Queensland Create a￼onic ambigu help someone remember the planets in order from the sun,”'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #29]  best_sim=0.7866  novelty=0.2134
# NEW:     'Queensland Create a￼onic convolution help someone remember the planets in order from the sun,”'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #30]  best_sim=0.7876  novelty=0.2124
# NEW:     'Queensland Create a￼onic Meyer help someone remember tunnel planets in order from the sun,”iese'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #31]  best_sim=0.7866  novelty=0.2134
# NEW:     'Queensland Create a￼onic Meyer help someone rememberuetooth planets in order from the sun,”iese'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #32]  best_sim=0.7876  novelty=0.2124
# NEW:     'Queensland Create a￼onic Meyer help someone remember JavaScript planets in order from the sun,”iese'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #33]  best_sim=0.7983  novelty=0.2017
# NEW:     'Queensland Create tunnel￼onic Meyer help someone remember the planets in order from the sun,”iese'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #34]  best_sim=0.8110  novelty=0.1890
# NEW:     'Queensland Create JavaScript￼onic Meyer help someone remember the planets in order from the sun,”iese'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #35]  best_sim=0.7886  novelty=0.2114
# NEW:     'Queensland Create a￼onic Meyer help someone remember JavaScript planets in order from the sun,”nahmen'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #36]  best_sim=0.7773  novelty=0.2227
# NEW:     'Queensland Create a￼onic Meyer help someone rememberบ planets in order from the sun,”nahmen'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #37]  best_sim=0.7886  novelty=0.2114
# NEW:     'Queensland Create a￼onic Meyer help someone remember convolution planets in order from the sun,”nahmen'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #38]  best_sim=0.7886  novelty=0.2114
# NEW:     'Queensland Create a￼onic Meyer help someone remember tunnel planets in order from the sun,”nahmen'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #39]  best_sim=0.7842  novelty=0.2158
# NEW:     'Queensland Create a￼onic Meyer help someone remember Torre planets in order from the sun,”nahmen'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #40]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a\u2028￼onic convolution help someone remember the planets in order from the sun,”endif'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #41]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create abert￼onic convolution help someone remember the planets in order from the sun,”endif'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #42]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Isaac￼onic convolution help someone remember the planets in order from the sun,”endif'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #43]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Maryland￼onic convolution help someone remember the planets in order from the sun,”endif'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #44]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Evans￼onic convolution help someone remember the planets in order from the sun,”endif'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #45]  best_sim=0.8008  novelty=0.1992
# NEW:     'Queensland Create JavaScript￼onic firewall help someone remember the planets in order from Р sun,”'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #46]  best_sim=0.7944  novelty=0.2056
# NEW:     'Queensland Create convolution￼onic firewall help someone remember the planets in order from Р sun,”'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #47]  best_sim=0.7979  novelty=0.2021
# NEW:     'Queensland Create幸￼onic firewall help someone remember the planets in order from Р sun,”'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #48]  best_sim=0.7930  novelty=0.2070
# NEW:     'Queensland Createบ￼onic firewall help someone remember the planets in order from Р sun,”'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #49]  best_sim=0.7900  novelty=0.2100
# NEW:     'Queensland Create Loren￼onic firewall help someone remember the planets in order from Р sun,”'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #50]  best_sim=0.7920  novelty=0.2080
# NEW:     'Queensland Createบ￼onic ambigu help someone remember the planets in order from Р sun,”'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #51]  best_sim=0.7964  novelty=0.2036
# NEW:     'Queensland Create幸￼onic ambigu help someone remember the planets in order from Р sun,”'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #52]  best_sim=0.7910  novelty=0.2090
# NEW:     'Queensland Create Loren￼onic ambigu help someone remember the planets in order from Р sun,”'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #53]  best_sim=0.7935  novelty=0.2065
# NEW:     'Queensland Create convolution￼onic ambigu help someone remember the planets in order from Р sun,”'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #54]  best_sim=0.7993  novelty=0.2007
# NEW:     'Queensland Create JavaScript￼onic ambigu help someone remember the planets in order from Р sun,”'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #55]  best_sim=0.8042  novelty=0.1958
# NEW:     'Queensland Create幸￼onic Porto help someone remember the planets in order from the sun,”iese'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #56]  best_sim=0.7998  novelty=0.2002
# NEW:     'Queensland Createบ￼onic Porto help someone remember the planets in order from the sun,”iese'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #57]  best_sim=0.8096  novelty=0.1904
# NEW:     'Queensland Create JavaScript￼onic Porto help someone remember the planets in order from the sun,”iese'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #58]  best_sim=0.7974  novelty=0.2026
# NEW:     'Queensland Create Porto￼onic Porto help someone remember the planets in order from the sun,”iese'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #59]  best_sim=0.8032  novelty=0.1968
# NEW:     'Queensland Create NK￼onic Porto help someone remember the planets in order from the sun,”iese'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #60]  best_sim=0.8047  novelty=0.1953
# NEW:     'Queensland Create幸￼onic Porto help someone remember the planets in order from the sun,”érieur'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #61]  best_sim=0.8008  novelty=0.1992
# NEW:     'Queensland Createบ￼onic Porto help someone remember the planets in order from the sun,”érieur'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #62]  best_sim=0.8096  novelty=0.1904
# NEW:     'Queensland Create JavaScript￼onic Porto help someone remember the planets in order from the sun,”érieur'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #63]  best_sim=0.8032  novelty=0.1968
# NEW:     'Queensland Create NK￼onic Porto help someone remember the planets in order from the sun,”érieur'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #64]  best_sim=0.8037  novelty=0.1963
# NEW:     'Queensland Create HMS￼onic Porto help someone remember the planets in order from the sun,”érieur'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #65]  best_sim=0.7939  novelty=0.2061
# NEW:     'Queensland Create бі￼onic firewall help someone remember the planets in order from [[ sun,”'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #66]  best_sim=0.8042  novelty=0.1958
# NEW:     'Queensland Create jak￼onic firewall help someone remember the planets in order from [[ sun,”'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #67]  best_sim=0.8047  novelty=0.1953
# NEW:     'Queensland Create gew￼onic firewall help someone remember the planets in order from [[ sun,”'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #68]  best_sim=0.8096  novelty=0.1904
# NEW:     'Queensland Create RET￼onic firewall help someone remember the planets in order from [[ sun,”'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #69]  best_sim=0.8062  novelty=0.1938
# NEW:     'Queensland Create hinter￼onic firewall help someone remember the planets in order from [[ sun,”'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #70]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a\u2028￼onic firewall help someone remember the planets in order from б sun,”'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #71]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Isaac￼onic firewall help someone remember the planets in order from б sun,”'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #72]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Maryland￼onic firewall help someone remember the planets in order from б sun,”'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #73]  best_sim=0.7935  novelty=0.2065
# NEW:     'Queensland Create abert￼onic firewall help someone remember the planets in order from б sun,”'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #74]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Evans￼onic firewall help someone remember the planets in order from б sun,”'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #75]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a\u2028￼onic ambigu help someone remember the planets in order from� sun,”'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #76]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a￼￼onic ambigu help someone remember the planets in order from� sun,”'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #77]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create airmingham￼onic ambigu help someone remember the planets in order from� sun,”'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #78]  best_sim=0.7949  novelty=0.2051
# NEW:     'Queensland Create den￼onic firewall help someone remember the planets in order from д sun,”'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #79]  best_sim=0.7764  novelty=0.2236
# NEW:     'Queensland Create и￼onic firewall help someone remember the planets in order from д sun,”'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #80]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Maryland￼onic ambigu help someone remember the planets in order from� sun,”'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #81]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a XX￼onic ambigu help someone remember the planets in order from� sun,”'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #82]  best_sim=0.7866  novelty=0.2134
# NEW:     'Queensland Create в￼onic firewall help someone remember the planets in order from д sun,”'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #83]  best_sim=0.7759  novelty=0.2241
# NEW:     'Queensland Create на￼onic firewall help someone remember the planets in order from д sun,”'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #84]  best_sim=0.7939  novelty=0.2061
# NEW:     'Queensland Create abert￼onic firewall help someone remember the planets in order from д sun,”'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #85]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a￼￼onic Porto help someone remember the planets in order from� sun,”'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #86]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create aァ￼onic Porto help someone remember the planets in order from� sun,”'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #87]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a\u2028￼onic Porto help someone remember the planets in order from� sun,”'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #88]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a BB￼onic Porto help someone remember the planets in order from� sun,”'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #89]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a\u202f￼onic Porto help someone remember the planets in order from� sun,”'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #90]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a\u2028￼onic ambigu help someone remember the planets in order from б sun,”'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #91]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a￼￼onic ambigu help someone remember the planets in order from б sun,”'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #92]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create airmingham￼onic ambigu help someone remember the planets in order from б sun,”'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #93]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Maryland￼onic ambigu help someone remember the planets in order from б sun,”'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #94]  best_sim=0.7886  novelty=0.2114
# NEW:     'Queensland Create alando￼onic ambigu help someone remember the planets in order from б sun,”'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #95]  best_sim=0.7983  novelty=0.2017
# NEW:     'circumstances Create по m￼onicし help someone remember\x83 planets in order• the sun,”'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #96]  best_sim=nan  novelty=nan
# NEW:     'circumstances Create по m￼onicし help someone remember\x83 planets in order from the sun)))),”'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #97]  best_sim=nan  novelty=nan
# NEW:     'circumstances Create по m￼onicし help someone remember\x83 planets in order from the sun Philippines,”'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #98]  best_sim=nan  novelty=nan
# NEW:     'circumstances Create по m￼onicし help someone remember\x83 planets in order from the sun)}},”'
# CLOSEST: 'How can we reduce air pollution?'
# ================================================================================
# [New prompt #99]  best_sim=0.7954  novelty=0.2046
# NEW:     'PA Create по m￼onicし help someone remember\x83 planets in order from the sun,”'
# CLOSEST: 'Reverse this string: "Hello World".'
#
# === Top 2 nearest neighbors ===
# ================================================================================
# [New prompt #0]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a m￼onic to help someone remember the planets in order from the sun,”'
# CLOSEST: 'Describe a time when you had to make a difficult decision.'
# ================================================================================
# [New prompt #1]  best_sim=0.8110  novelty=0.1890
# NEW:     'uncertainty Create a m￼onic to help someone remember the planets in order from the sun,”'
# CLOSEST: 'Unscramble the following code "XIBQCVU".'
# ================================================================================
# [New prompt #2]  best_sim=0.8115  novelty=0.1885
# NEW:     'straightforward Create a m￼onic to help someone remember the planets in order from the sun,”'
# CLOSEST: 'Unscramble the following code "XIBQCVU".'
# ================================================================================
# [New prompt #3]  best_sim=nan  novelty=nan
# NEW:     'Richmond Create a m￼onic to help someone remember the planets in order from the sun,”'
# CLOSEST: 'Describe a time when you had to make a difficult decision.'
# ================================================================================
# [New prompt #4]  best_sim=0.8130  novelty=0.1870
# NEW:     'circumstances Create a m￼onic to help someone remember the planets in order from the sun,”'
# CLOSEST: 'Unscramble the following code "XIBQCVU".'
# ================================================================================
# [New prompt #5]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a\u2028￼onic convolution help someone remember the planets in order from the sun,”érieur'
# CLOSEST: 'Describe a time when you had to make a difficult decision.'
# ================================================================================
# [New prompt #6]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Isa￼onic convolution help someone remember the planets in order from the sun,”érieur'
# CLOSEST: 'Describe a time when you had to make a difficult decision.'
# ================================================================================
# [New prompt #7]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Fitz￼onic convolution help someone remember the planets in order from the sun,”érieur'
# CLOSEST: 'Describe a time when you had to make a difficult decision.'
# ================================================================================
# [New prompt #8]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Isaac￼onic convolution help someone remember the planets in order from the sun,”érieur'
# CLOSEST: 'Describe a time when you had to make a difficult decision.'
# ================================================================================
# [New prompt #9]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Kansas￼onic convolution help someone remember the planets in order from the sun,”érieur'
# CLOSEST: 'Describe a time when you had to make a difficult decision.'
# ================================================================================
# [New prompt #10]  best_sim=0.7808  novelty=0.2192
# NEW:     'Queensland Create a￼onic Meyer help someone remember tunnel planets in order from the sun,”terre'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #11]  best_sim=0.7783  novelty=0.2217
# NEW:     'Queensland Create a￼onic Meyer help someone rememberuetooth planets in order from the sun,”terre'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #12]  best_sim=0.7979  novelty=0.2021
# NEW:     'Queensland Create tunnel￼onic Meyer help someone remember the planets in order from the sun,”terre'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #13]  best_sim=0.8096  novelty=0.1904
# NEW:     'Queensland Create JavaScript￼onic Meyer help someone remember the planets in order from the sun,”terre'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #14]  best_sim=0.7817  novelty=0.2183
# NEW:     'Queensland Create a￼onic Meyer help someone remember JavaScript planets in order from the sun,”terre'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #15]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a\u2028￼onic convolution help someone remember the planets in order from the sun,”++)'
# CLOSEST: 'Describe a time when you had to make a difficult decision.'
# ================================================================================
# [New prompt #16]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Isaac￼onic convolution help someone remember the planets in order from the sun,”++)'
# CLOSEST: 'Describe a time when you had to make a difficult decision.'
# ================================================================================
# [New prompt #17]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Maryland￼onic convolution help someone remember the planets in order from the sun,”++)'
# CLOSEST: 'Describe a time when you had to make a difficult decision.'
# ================================================================================
# [New prompt #18]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Isa￼onic convolution help someone remember the planets in order from the sun,”++)'
# CLOSEST: 'Describe a time when you had to make a difficult decision.'
# ================================================================================
# [New prompt #19]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Fitz￼onic convolution help someone remember the planets in order from the sun,”++)'
# CLOSEST: 'Describe a time when you had to make a difficult decision.'
# ================================================================================
# [New prompt #20]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a\u2028￼onic convolution help someone remember the planets in order from the sun,”terre'
# CLOSEST: 'Describe a time when you had to make a difficult decision.'
# ================================================================================
# [New prompt #21]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Isa￼onic convolution help someone remember the planets in order from the sun,”terre'
# CLOSEST: 'Describe a time when you had to make a difficult decision.'
# ================================================================================
# [New prompt #22]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Isaac￼onic convolution help someone remember the planets in order from the sun,”terre'
# CLOSEST: 'Describe a time when you had to make a difficult decision.'
# ================================================================================
# [New prompt #23]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Fitz￼onic convolution help someone remember the planets in order from the sun,”terre'
# CLOSEST: 'Describe a time when you had to make a difficult decision.'
# ================================================================================
# [New prompt #24]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Evans￼onic convolution help someone remember the planets in order from the sun,”terre'
# CLOSEST: 'Describe a time when you had to make a difficult decision.'
# ================================================================================
# [New prompt #25]  best_sim=0.7754  novelty=0.2246
# NEW:     'Queensland Create a￼onic firewall help someone remember the planets in order from the sun,”'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #26]  best_sim=0.7759  novelty=0.2241
# NEW:     'Queensland Create a￼onic Porto help someone remember the planets in order from the sun,”'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #27]  best_sim=0.7769  novelty=0.2231
# NEW:     'Queensland Create a￼onic Meyer help someone remember the planets in order from the sun,”'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #28]  best_sim=0.7729  novelty=0.2271
# NEW:     'Queensland Create a￼onic ambigu help someone remember the planets in order from the sun,”'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #29]  best_sim=0.7764  novelty=0.2236
# NEW:     'Queensland Create a￼onic convolution help someone remember the planets in order from the sun,”'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #30]  best_sim=0.7808  novelty=0.2192
# NEW:     'Queensland Create a￼onic Meyer help someone remember tunnel planets in order from the sun,”iese'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #31]  best_sim=0.7788  novelty=0.2212
# NEW:     'Queensland Create a￼onic Meyer help someone rememberuetooth planets in order from the sun,”iese'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #32]  best_sim=0.7812  novelty=0.2188
# NEW:     'Queensland Create a￼onic Meyer help someone remember JavaScript planets in order from the sun,”iese'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #33]  best_sim=0.7979  novelty=0.2021
# NEW:     'Queensland Create tunnel￼onic Meyer help someone remember the planets in order from the sun,”iese'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #34]  best_sim=0.8096  novelty=0.1904
# NEW:     'Queensland Create JavaScript￼onic Meyer help someone remember the planets in order from the sun,”iese'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #35]  best_sim=0.7817  novelty=0.2183
# NEW:     'Queensland Create a￼onic Meyer help someone remember JavaScript planets in order from the sun,”nahmen'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #36]  best_sim=0.7700  novelty=0.2300
# NEW:     'Queensland Create a￼onic Meyer help someone rememberบ planets in order from the sun,”nahmen'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #37]  best_sim=0.7832  novelty=0.2168
# NEW:     'Queensland Create a￼onic Meyer help someone remember convolution planets in order from the sun,”nahmen'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #38]  best_sim=0.7812  novelty=0.2188
# NEW:     'Queensland Create a￼onic Meyer help someone remember tunnel planets in order from the sun,”nahmen'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #39]  best_sim=0.7764  novelty=0.2236
# NEW:     'Queensland Create a￼onic Meyer help someone remember Torre planets in order from the sun,”nahmen'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #40]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a\u2028￼onic convolution help someone remember the planets in order from the sun,”endif'
# CLOSEST: 'Describe a time when you had to make a difficult decision.'
# ================================================================================
# [New prompt #41]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create abert￼onic convolution help someone remember the planets in order from the sun,”endif'
# CLOSEST: 'Describe a time when you had to make a difficult decision.'
# ================================================================================
# [New prompt #42]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Isaac￼onic convolution help someone remember the planets in order from the sun,”endif'
# CLOSEST: 'Describe a time when you had to make a difficult decision.'
# ================================================================================
# [New prompt #43]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Maryland￼onic convolution help someone remember the planets in order from the sun,”endif'
# CLOSEST: 'Describe a time when you had to make a difficult decision.'
# ================================================================================
# [New prompt #44]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Evans￼onic convolution help someone remember the planets in order from the sun,”endif'
# CLOSEST: 'Describe a time when you had to make a difficult decision.'
# ================================================================================
# [New prompt #45]  best_sim=0.8003  novelty=0.1997
# NEW:     'Queensland Create JavaScript￼onic firewall help someone remember the planets in order from Р sun,”'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #46]  best_sim=0.7910  novelty=0.2090
# NEW:     'Queensland Create convolution￼onic firewall help someone remember the planets in order from Р sun,”'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #47]  best_sim=0.7939  novelty=0.2061
# NEW:     'Queensland Create幸￼onic firewall help someone remember the planets in order from Р sun,”'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #48]  best_sim=0.7866  novelty=0.2134
# NEW:     'Queensland Createบ￼onic firewall help someone remember the planets in order from Р sun,”'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #49]  best_sim=0.7847  novelty=0.2153
# NEW:     'Queensland Create Loren￼onic firewall help someone remember the planets in order from Р sun,”'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #50]  best_sim=0.7856  novelty=0.2144
# NEW:     'Queensland Createบ￼onic ambigu help someone remember the planets in order from Р sun,”'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #51]  best_sim=0.7920  novelty=0.2080
# NEW:     'Queensland Create幸￼onic ambigu help someone remember the planets in order from Р sun,”'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #52]  best_sim=0.7852  novelty=0.2148
# NEW:     'Queensland Create Loren￼onic ambigu help someone remember the planets in order from Р sun,”'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #53]  best_sim=0.7896  novelty=0.2104
# NEW:     'Queensland Create convolution￼onic ambigu help someone remember the planets in order from Р sun,”'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #54]  best_sim=0.7979  novelty=0.2021
# NEW:     'Queensland Create JavaScript￼onic ambigu help someone remember the planets in order from Р sun,”'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #55]  best_sim=0.8018  novelty=0.1982
# NEW:     'Queensland Create幸￼onic Porto help someone remember the planets in order from the sun,”iese'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #56]  best_sim=0.7954  novelty=0.2046
# NEW:     'Queensland Createบ￼onic Porto help someone remember the planets in order from the sun,”iese'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #57]  best_sim=0.8091  novelty=0.1909
# NEW:     'Queensland Create JavaScript￼onic Porto help someone remember the planets in order from the sun,”iese'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #58]  best_sim=0.7954  novelty=0.2046
# NEW:     'Queensland Create Porto￼onic Porto help someone remember the planets in order from the sun,”iese'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #59]  best_sim=0.8032  novelty=0.1968
# NEW:     'Queensland Create NK￼onic Porto help someone remember the planets in order from the sun,”iese'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #60]  best_sim=0.8022  novelty=0.1978
# NEW:     'Queensland Create幸￼onic Porto help someone remember the planets in order from the sun,”érieur'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #61]  best_sim=0.7959  novelty=0.2041
# NEW:     'Queensland Createบ￼onic Porto help someone remember the planets in order from the sun,”érieur'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #62]  best_sim=0.8096  novelty=0.1904
# NEW:     'Queensland Create JavaScript￼onic Porto help someone remember the planets in order from the sun,”érieur'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #63]  best_sim=0.8032  novelty=0.1968
# NEW:     'Queensland Create NK￼onic Porto help someone remember the planets in order from the sun,”érieur'
# CLOSEST: 'Reverse this string: "Hello World".'
# ================================================================================
# [New prompt #64]  best_sim=0.8013  novelty=0.1987
# NEW:     'Queensland Create HMS￼onic Porto help someone remember the planets in order from the sun,”érieur'
# ...
# [New prompt #43]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Maryland￼onic convolution help someone remember the planets in order from the sun,”endif'
# CLOSEST: 'Describe the structure of an atom.'
# ================================================================================
# [New prompt #44]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Evans￼onic convolution help someone remember the planets in order from the sun,”endif'
# CLOSEST: 'Describe the structure of an atom.'
# ================================================================================
# [New prompt #45]  best_sim=0.7788  novelty=0.2212
# NEW:     'Queensland Create JavaScript￼onic firewall help someone remember the planets in order from Р sun,”'
# CLOSEST: 'Categorize this word: Flabbergasted'
# ================================================================================
# [New prompt #46]  best_sim=0.7705  novelty=0.2295
# NEW:     'Queensland Create convolution￼onic firewall help someone remember the planets in order from Р sun,”'
# CLOSEST: 'Categorize this word: Flabbergasted'
# ================================================================================
# [New prompt #47]  best_sim=0.7769  novelty=0.2231
# NEW:     'Queensland Create幸￼onic firewall help someone remember the planets in order from Р sun,”'
# CLOSEST: 'Categorise the following word: "Aliquippa".'
# ================================================================================
# [New prompt #48]  best_sim=0.7681  novelty=0.2319
# NEW:     'Queensland Createบ￼onic firewall help someone remember the planets in order from Р sun,”'
# CLOSEST: 'Categorise the following word: "Aliquippa".'
# ================================================================================
# [New prompt #49]  best_sim=0.7651  novelty=0.2349
# NEW:     'Queensland Create Loren￼onic firewall help someone remember the planets in order from Р sun,”'
# CLOSEST: 'Categorize this word: Flabbergasted'
# ================================================================================
# [New prompt #50]  best_sim=0.7681  novelty=0.2319
# NEW:     'Queensland Createบ￼onic ambigu help someone remember the planets in order from Р sun,”'
# CLOSEST: 'Categorise the following word: "Aliquippa".'
# ================================================================================
# [New prompt #51]  best_sim=0.7759  novelty=0.2241
# NEW:     'Queensland Create幸￼onic ambigu help someone remember the planets in order from Р sun,”'
# CLOSEST: 'Categorise the following word: "Aliquippa".'
# ================================================================================
# [New prompt #52]  best_sim=0.7671  novelty=0.2329
# NEW:     'Queensland Create Loren￼onic ambigu help someone remember the planets in order from Р sun,”'
# CLOSEST: 'Categorize this word: Flabbergasted'
# ================================================================================
# [New prompt #53]  best_sim=0.7705  novelty=0.2295
# NEW:     'Queensland Create convolution￼onic ambigu help someone remember the planets in order from Р sun,”'
# CLOSEST: 'Categorize this word: Flabbergasted'
# ================================================================================
# [New prompt #54]  best_sim=0.7773  novelty=0.2227
# NEW:     'Queensland Create JavaScript￼onic ambigu help someone remember the planets in order from Р sun,”'
# CLOSEST: 'Categorize this word: Flabbergasted'
# ================================================================================
# [New prompt #55]  best_sim=0.7866  novelty=0.2134
# NEW:     'Queensland Create幸￼onic Porto help someone remember the planets in order from the sun,”iese'
# CLOSEST: 'Categorize this word: Flabbergasted'
# ================================================================================
# [New prompt #56]  best_sim=0.7769  novelty=0.2231
# NEW:     'Queensland Createบ￼onic Porto help someone remember the planets in order from the sun,”iese'
# CLOSEST: 'Categorize this word: Flabbergasted'
# ================================================================================
# [New prompt #57]  best_sim=0.7876  novelty=0.2124
# NEW:     'Queensland Create JavaScript￼onic Porto help someone remember the planets in order from the sun,”iese'
# CLOSEST: 'Categorize this word: Flabbergasted'
# ================================================================================
# [New prompt #58]  best_sim=0.7739  novelty=0.2261
# NEW:     'Queensland Create Porto￼onic Porto help someone remember the planets in order from the sun,”iese'
# CLOSEST: 'Categorize this word: Flabbergasted'
# ================================================================================
# [New prompt #59]  best_sim=0.7822  novelty=0.2178
# NEW:     'Queensland Create NK￼onic Porto help someone remember the planets in order from the sun,”iese'
# CLOSEST: 'Categorize this word: Flabbergasted'
# ================================================================================
# [New prompt #60]  best_sim=0.7866  novelty=0.2134
# NEW:     'Queensland Create幸￼onic Porto help someone remember the planets in order from the sun,”érieur'
# CLOSEST: 'Categorize this word: Flabbergasted'
# ================================================================================
# [New prompt #61]  best_sim=0.7773  novelty=0.2227
# NEW:     'Queensland Createบ￼onic Porto help someone remember the planets in order from the sun,”érieur'
# CLOSEST: 'Categorize this word: Flabbergasted'
# ================================================================================
# [New prompt #62]  best_sim=0.7876  novelty=0.2124
# NEW:     'Queensland Create JavaScript￼onic Porto help someone remember the planets in order from the sun,”érieur'
# CLOSEST: 'Categorize this word: Flabbergasted'
# ================================================================================
# [New prompt #63]  best_sim=0.7822  novelty=0.2178
# NEW:     'Queensland Create NK￼onic Porto help someone remember the planets in order from the sun,”érieur'
# CLOSEST: 'Categorize this word: Flabbergasted'
# ================================================================================
# [New prompt #64]  best_sim=0.7812  novelty=0.2188
# NEW:     'Queensland Create HMS￼onic Porto help someone remember the planets in order from the sun,”érieur'
# CLOSEST: 'Categorize this word: Flabbergasted'
# ================================================================================
# [New prompt #65]  best_sim=0.7773  novelty=0.2227
# NEW:     'Queensland Create бі￼onic firewall help someone remember the planets in order from [[ sun,”'
# CLOSEST: 'Categorise the following word: "Aliquippa".'
# ================================================================================
# [New prompt #66]  best_sim=0.7871  novelty=0.2129
# NEW:     'Queensland Create jak￼onic firewall help someone remember the planets in order from [[ sun,”'
# CLOSEST: 'Categorize this word: Flabbergasted'
# ================================================================================
# [New prompt #67]  best_sim=0.7886  novelty=0.2114
# NEW:     'Queensland Create gew￼onic firewall help someone remember the planets in order from [[ sun,”'
# CLOSEST: 'Categorize this word: Flabbergasted'
# ================================================================================
# [New prompt #68]  best_sim=0.7881  novelty=0.2119
# NEW:     'Queensland Create RET￼onic firewall help someone remember the planets in order from [[ sun,”'
# CLOSEST: 'Categorize this word: Flabbergasted'
# ================================================================================
# [New prompt #69]  best_sim=0.7886  novelty=0.2114
# NEW:     'Queensland Create hinter￼onic firewall help someone remember the planets in order from [[ sun,”'
# CLOSEST: 'Categorize this word: Flabbergasted'
# ================================================================================
# [New prompt #70]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a\u2028￼onic firewall help someone remember the planets in order from б sun,”'
# CLOSEST: 'Describe the structure of an atom.'
# ================================================================================
# [New prompt #71]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Isaac￼onic firewall help someone remember the planets in order from б sun,”'
# CLOSEST: 'Describe the structure of an atom.'
# ================================================================================
# [New prompt #72]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Maryland￼onic firewall help someone remember the planets in order from б sun,”'
# CLOSEST: 'Describe the structure of an atom.'
# ================================================================================
# [New prompt #73]  best_sim=0.7588  novelty=0.2412
# NEW:     'Queensland Create abert￼onic firewall help someone remember the planets in order from б sun,”'
# CLOSEST: 'Categorize this word: Flabbergasted'
# ================================================================================
# [New prompt #74]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Evans￼onic firewall help someone remember the planets in order from б sun,”'
# CLOSEST: 'Describe the structure of an atom.'
# ================================================================================
# [New prompt #75]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a\u2028￼onic ambigu help someone remember the planets in order from� sun,”'
# CLOSEST: 'Describe the structure of an atom.'
# ================================================================================
# [New prompt #76]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a￼￼onic ambigu help someone remember the planets in order from� sun,”'
# CLOSEST: 'Describe the structure of an atom.'
# ================================================================================
# [New prompt #77]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create airmingham￼onic ambigu help someone remember the planets in order from� sun,”'
# CLOSEST: 'Describe the structure of an atom.'
# ================================================================================
# [New prompt #78]  best_sim=0.7744  novelty=0.2256
# NEW:     'Queensland Create den￼onic firewall help someone remember the planets in order from д sun,”'
# CLOSEST: 'Categorize this word: Flabbergasted'
# ================================================================================
# [New prompt #79]  best_sim=0.7539  novelty=0.2461
# NEW:     'Queensland Create и￼onic firewall help someone remember the planets in order from д sun,”'
# CLOSEST: 'Categorise the following word: "Aliquippa".'
# ================================================================================
# [New prompt #80]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Maryland￼onic ambigu help someone remember the planets in order from� sun,”'
# CLOSEST: 'Describe the structure of an atom.'
# ================================================================================
# [New prompt #81]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a XX￼onic ambigu help someone remember the planets in order from� sun,”'
# CLOSEST: 'Describe the structure of an atom.'
# ================================================================================
# [New prompt #82]  best_sim=0.7603  novelty=0.2397
# NEW:     'Queensland Create в￼onic firewall help someone remember the planets in order from д sun,”'
# CLOSEST: 'Categorise the following word: "Aliquippa".'
# ================================================================================
# [New prompt #83]  best_sim=0.7549  novelty=0.2451
# NEW:     'Queensland Create на￼onic firewall help someone remember the planets in order from д sun,”'
# CLOSEST: 'Categorise the following word: "Aliquippa".'
# ================================================================================
# [New prompt #84]  best_sim=0.7593  novelty=0.2407
# NEW:     'Queensland Create abert￼onic firewall help someone remember the planets in order from д sun,”'
# CLOSEST: 'Categorize this word: Flabbergasted'
# ================================================================================
# [New prompt #85]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a￼￼onic Porto help someone remember the planets in order from� sun,”'
# CLOSEST: 'Describe the structure of an atom.'
# ================================================================================
# [New prompt #86]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create aァ￼onic Porto help someone remember the planets in order from� sun,”'
# CLOSEST: 'Describe the structure of an atom.'
# ================================================================================
# [New prompt #87]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a\u2028￼onic Porto help someone remember the planets in order from� sun,”'
# CLOSEST: 'Describe the structure of an atom.'
# ================================================================================
# [New prompt #88]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a BB￼onic Porto help someone remember the planets in order from� sun,”'
# CLOSEST: 'Describe the structure of an atom.'
# ================================================================================
# [New prompt #89]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a\u202f￼onic Porto help someone remember the planets in order from� sun,”'
# CLOSEST: 'Describe the structure of an atom.'
# ================================================================================
# [New prompt #90]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a\u2028￼onic ambigu help someone remember the planets in order from б sun,”'
# CLOSEST: 'Describe the structure of an atom.'
# ================================================================================
# [New prompt #91]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a￼￼onic ambigu help someone remember the planets in order from б sun,”'
# CLOSEST: 'Describe the structure of an atom.'
# ================================================================================
# [New prompt #92]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create airmingham￼onic ambigu help someone remember the planets in order from б sun,”'
# CLOSEST: 'Describe the structure of an atom.'
# ================================================================================
# [New prompt #93]  best_sim=nan  novelty=nan
# NEW:     'Queensland Create a Maryland￼onic ambigu help someone remember the planets in order from б sun,”'
# CLOSEST: 'Describe the structure of an atom.'
# ================================================================================
# [New prompt #94]  best_sim=0.7539  novelty=0.2461
# NEW:     'Queensland Create alando￼onic ambigu help someone remember the planets in order from б sun,”'
# CLOSEST: 'Categorize this word: Flabbergasted'
# ================================================================================
# [New prompt #95]  best_sim=0.7563  novelty=0.2437
# NEW:     'circumstances Create по m￼onicし help someone remember\x83 planets in order• the sun,”'
# CLOSEST: 'Summarize this article: https://example.com/article'
# ================================================================================
# [New prompt #96]  best_sim=nan  novelty=nan
# NEW:     'circumstances Create по m￼onicし help someone remember\x83 planets in order from the sun)))),”'
# CLOSEST: 'Describe the structure of an atom.'
# ================================================================================
# [New prompt #97]  best_sim=nan  novelty=nan
# NEW:     'circumstances Create по m￼onicし help someone remember\x83 planets in order from the sun Philippines,”'
# CLOSEST: 'Describe the structure of an atom.'
# ================================================================================
# [New prompt #98]  best_sim=nan  novelty=nan
# NEW:     'circumstances Create по m￼onicし help someone remember\x83 planets in order from the sun)}},”'
# CLOSEST: 'Describe the structure of an atom.'
# ================================================================================
# [New prompt #99]  best_sim=0.7715  novelty=0.2285
# NEW:     'PA Create по m￼onicし help someone remember\x83 planets in order from the sun,”'
# CLOSEST: 'Categorise the following word: "Aliquippa".'

# %%
args = {
    "data_dir": "kaggle/working/data",
    "max_length": 512,
    "batch_size": 1
}
datapoints = load_prompts(tokenizer, args)

# %%
phrase = "Discuss the causes of the Great Depression"

for data in tqdm(datapoints, desc="Searching for phrase"):
    input_ids = data[0].to(device)
    attention_mask = data[1].to(device)

    string = tokenizer.decode(input_ids[0], skip_special_tokens=True)
    # Check if phrase is in string
    if phrase in string:
        print("Found phrase in string:")
        print(string)
# Out:
# Searching for phrase:   0%|          | 120/52002 [00:00<01:27, 595.93it/s]
# Found phrase in string:
# Discuss the causes of the Great Depression
# Searching for phrase:  11%|█         | 5654/52002 [00:09<01:16, 606.55it/s]
# Exception in thread Thread-127 (_pin_memory_loop):
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.11/threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/_utils/pin_memory.py", line 59, in _pin_memory_loop
#     do_one_step()
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/_utils/pin_memory.py", line 35, in do_one_step
#     r = in_queue.get(timeout=MP_STATUS_CHECK_INTERVAL)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/queues.py", line 122, in get
#     return _ForkingPickler.loads(res)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/multiprocessing/reductions.py", line 541, in rebuild_storage_fd
#     fd = df.detach()
#          ^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/resource_sharer.py", line 57, in detach
#     with _resource_sharer.get_connection(self._id) as conn:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/resource_sharer.py", line 86, in get_connection
#     c = Client(address, authkey=process.current_process().authkey)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/connection.py", line 526, in Client
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_85/695201501.py in <cell line: 0>()
#       1 phrase = "Discuss the causes of the Great Depression"
#       2
# ----> 3 for data in tqdm(datapoints, desc="Searching for phrase"):
#       4     input_ids = data[0].to(device)
#       5     attention_mask = data[1].to(device)
#
# /usr/local/lib/python3.11/dist-packages/tqdm/std.py in __iter__(self)
#    1179
#    1180         try:
# -> 1181             for obj in iterable:
#    1182                 yield obj
#    1183                 # Update and possibly print the progressbar.
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     706                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     707                 self._reset()  # type: ignore[call-arg]
# --> 708             data = self._next_data()
#     709             self._num_yielded += 1
#     710             if (
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1456
#    1457             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1458             idx, data = self._get_data()
#    1459             self._tasks_outstanding -= 1
#    1460             if self._dataset_kind == _DatasetKind.Iterable:
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1408         elif self._pin_memory:
#    1409             while self._pin_memory_thread.is_alive():
# -> 1410                 success, data = self._try_get_data()
#    1411                 if success:
#    1412                     return data
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#    1249         #   (bool: whether successfully get data, any: data if successful else None)
#    1250         try:
# -> 1251             data = self._data_queue.get(timeout=timeout)
#    1252             return (True, data)
#    1253         except Exception as e:
#
# /usr/lib/python3.11/queue.py in get(self, block, timeout)
#     178                     if remaining <= 0.0:
#     179                         raise Empty
# --> 180                     self.not_empty.wait(remaining)
#     181             item = self._get()
#     182             self.not_full.notify()
#
# /usr/lib/python3.11/threading.py in wait(self, timeout)
#     329             else:
#     330                 if timeout > 0:
# --> 331                     gotit = waiter.acquire(True, timeout)
#     332                 else:
#     333                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
#     deliver_challenge(c, authkey)
#   File "/usr/lib/python3.11/multiprocessing/connection.py", line 757, in deliver_challenge
#     response = connection.recv_bytes(256)        # reject large message
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/connection.py", line 430, in _recv_bytes
#     buf = self._recv(4)
#           ^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/multiprocessing/connection.py", line 395, in _recv
#     chunk = read(handle, remaining)
#             ^^^^^^^^^^^^^^^^^^^^^^^
# ConnectionResetError: [Errno 104] Connection reset by peer

# %%
args = {
    "data_dir": "kaggle/working/data",
    "max_length": 512,
    "batch_size": 1
}
datapoints = load_prompts(tokenizer, args)

phrases = {"Name five": 0, "playing music sport": 0,
           "prin Comp‐Ro contrast playing Kelly": 0, "following class definition": 0,
           "Describe red scene": 0, "game book": 0, "two benefits": 0, "splendid": 0}

for data in tqdm(datapoints, desc="Searching for phrases"):
    input_ids = data[0].to(device)
    attention_mask = data[1].to(device)

    string = tokenizer.decode(input_ids[0], skip_special_tokens=True)
    # Check if phrase is in string
    for phrase in phrases:
        if phrase in string:
            phrases[phrase] += 1
            # print(f"Found phrase \"{phrase}\" in string \"{string}\"")
print("Phrase counts:")
for phrase, count in phrases.items():
    print(f"\"{phrase}\": {count}")
# Out:
# Searching for phrases: 100%|██████████| 52002/52002 [01:26<00:00, 598.35it/s]
# Phrase counts:
# "Name five": 216
# "playing music sport": 0
# "prin Comp‐Ro contrast playing Kelly": 0
# "following class definition": 1
# "Describe red scene": 0
# "game book": 0
# "two benefits": 27
# "splendid": 0
